# %% [markdown]
# # Model training
#
# Trains SVC on the seqFISH+ arrays built in [Data preprocessing](preprocess.ipynb), by running
# `seqfish/train.py`.
#
# Reads
#
# - `train_seqfish.npz` — the model inputs, written by `seqfish/prepare_data.py`
# - `gene2vec_weight_seqfish.npy` — the Gene2vec vector of each gene in the panel
#
# Writes into `--out-dir`
#
# - `checkpoint.pth`, `train_losses.npy`, `val_losses.npy`

# %%
import os
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np

SVC_ROOT = Path(os.environ.get('SVC_ROOT', '../../..'))   # github.com/aster-ww/SVC
DATA_ROOT = Path(os.environ.get('SVC_DATA_ROOT', '../../../data'))
OUT_DIR = Path('../../../output/seqfish')

# %% [markdown]
# **required model inputs**
#
# - `data_ori`: inputs for *gene-level subcellular localization embedding*
#
# - `gene2vec_weight`: inputs for *gene-level functional embedding*
#
# - `cell_morphology, nuclear_morphology`: inputs for *cell-level morphological embedding*
#
# - `location`: inputs for *cell-level neighbor embedding*
#
# - `identity_label`(optional): inputs for *cell-level identity embeddings*

# %%
# !python {SVC_ROOT}/seqfish/train.py --data-root {DATA_ROOT} --out-dir {OUT_DIR}
# Out:
# [seqfish] train=145  val(batches=[1])=12  genes=1000  identity_types=3
# Building per-cell k-NN (k_max=4, K_SCALES=(4,)) within each batch ...
#   [warn] batch 11: 4 cells < k+1=5 — last 1 slot(s) padded
#   built kNN: N=145, k=4, batches=15, short=4
#   built kNN: N=12, k=4, batches=1, short=0
#   tau_per_scale_train=['657.65'], tau_per_scale_val=['663.93']
#   D4 augmentation: True
#   AMP(bf16 autocast): False
# Starting seqfish training (lambda 0->10.0 over ep 50->100, patience=50)...
# Epoch 1/400  train=106.6449  val=136.1800  patience=0/50
# Epoch 10/400  train=51.7774  val=63.4655  patience=0/50
# Epoch 20/400  train=47.0479  val=58.0490  patience=0/50
# Epoch 30/400  train=47.4279  val=57.2370  patience=0/50
# Epoch 40/400  train=46.7931  val=55.7302  patience=0/50
# Epoch 50/400  train=44.7226  val=53.1793  patience=0/50
# Epoch 60/400  train=43.5754  val=51.7623  patience=0/50
# Epoch 70/400  train=43.5490  val=50.5399  patience=0/50
# ...

# %%
train_losses = np.load(OUT_DIR / 'train_losses.npy')
val_losses = np.load(OUT_DIR / 'val_losses.npy')

fig, ax = plt.subplots(figsize=(6, 4))
ax.plot(np.arange(1, len(train_losses) + 1), train_losses, label='train')
ax.plot(np.arange(1, len(val_losses) + 1), val_losses, label='validation')
ax.set_xlabel('epoch')
ax.set_ylabel('loss')
ax.legend()
plt.tight_layout()
plt.show()
